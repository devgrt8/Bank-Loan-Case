# %%
# Import primary libraries for data and visualization

import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import of cv in DataFrame and printing top 5 rows using head function

df=pd.read_csv('bank-loan.csv')
df.head()
# Out:
#    age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0   41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1   27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2   40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3   41   1      15       14     120      2.9   2.658720  0.821280      0.0
# 4   24   2       2        0      28     17.3   1.787436  3.056564      1.0

# %%
# gives statistical overview of data in terms of mean, median and standard deviation

df.describe()
# Out:
#               age          ed      employ     address      income     debtinc  \
# count  850.000000  850.000000  850.000000  850.000000  850.000000  850.000000
# mean    35.029412    1.710588    8.565882    8.371765   46.675294   10.171647
# std      8.041432    0.927784    6.777884    6.895016   38.543054    6.719441
# min     20.000000    1.000000    0.000000    0.000000   13.000000    0.100000
# 25%     29.000000    1.000000    3.000000    3.000000   24.000000    5.100000
# 50%     34.000000    1.000000    7.000000    7.000000   35.000000    8.700000
# 75%     41.000000    2.000000   13.000000   12.000000   55.750000   13.800000
# max     56.000000    5.000000   33.000000   34.000000  446.000000   41.300000
#
#          creddebt     othdebt     default
# count  850.000000  850.000000  700.000000
# mean     1.576805    3.078789    0.261429
# std      2.125840    3.398803    0.439727
# min      0.011696    0.045584    0.000000
# 25%      0.382176    1.045942    0.000000
# ...

# %%
# Data types of all variable 

df.dtypes
# Out:
# age           int64
# ed            int64
# employ        int64
# address       int64
# income        int64
# debtinc     float64
# creddebt    float64
# othdebt     float64
# default     float64
# dtype: object

# %%
# Finding out missing values in each variable 

missing_df=df.isnull().sum()
missing_df = pd.DataFrame(missing_df, columns= ['Missing Counts'])
missing_df
# Out:
#           Missing Counts
# age                    0
# ed                     0
# employ                 0
# address                0
# income                 0
# debtinc                0
# creddebt               0
# othdebt                0
# default              150

# %%
# Splitting train data from original csv data file 

train = df.iloc[:700].copy()

# %%
# Splitting test data from original csv data file 


test = df.iloc[700:].copy()

# %%
# Drop th target variable from test dataset which we have to predict

test.drop(['default'],axis=1, inplace=True)

# %%
# Distribution or value counts in target variable

train['default'].value_counts()
# Out:
# 0.0    517
# 1.0    183
# Name: default, dtype: int64

# %%
# Distribution of default value in train data

fig=sns.countplot(x='default',data=train)

# %% [markdown]
# ## Distribution of each variable on basis of target variable 0 and 1 for distribution over data

# %%
t0 = train.loc[train['default'] == 0]
t1 = train.loc[train['default'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of age in the train set for different target")
sns.distplot(t0['age'],color="red", kde=True,bins=50, label='target = 0')
sns.distplot(t1['age'],color="blue", kde=True,bins=50, label='target = 1')
plt.legend()
plt.show()

# %%
t0 = train.loc[train['default'] == 0]
t1 = train.loc[train['default'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of ed in the train set for different target")
sns.distplot(t0['ed'],color="red", kde=True,bins=50, label='target = 0')
sns.distplot(t1['ed'],color="blue", kde=True,bins=50, label='target = 1')
plt.legend()
plt.show()

# %%
t0 = train.loc[train['default'] == 0]
t1 = train.loc[train['default'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of employ in the train set for different target")
sns.distplot(t0['employ'],color="red", kde=True,bins=50, label='target = 0')
sns.distplot(t1['employ'],color="blue", kde=True,bins=50, label='target = 1')
plt.legend()
plt.show()

# %%
t0 = train.loc[train['default'] == 0]
t1 = train.loc[train['default'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of address in the train set for different target")
sns.distplot(t0['address'],color="red", kde=True,bins=50, label='target = 0')
sns.distplot(t1['address'],color="blue", kde=True,bins=50, label='target = 1')
plt.legend()
plt.show()

# %%
t0 = train.loc[train['default'] == 0]
t1 = train.loc[train['default'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of income in the train set for different target")
sns.distplot(t0['income'],color="red", kde=True,bins=50, label='target = 0')
sns.distplot(t1['income'],color="blue", kde=True,bins=50, label='target = 1')
plt.legend()
plt.show()

# %%
t0 = train.loc[train['default'] == 0]
t1 = train.loc[train['default'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of debtinc in the train set for different target")
sns.distplot(t0['debtinc'],color="red", kde=True,bins=50, label='target = 0')
sns.distplot(t1['debtinc'],color="blue", kde=True,bins=50, label='target = 1')
plt.legend()
plt.show()

# %%
t0 = train.loc[train['default'] == 0]
t1 = train.loc[train['default'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of creddebt in the train set for different target")
sns.distplot(t0['creddebt'],color="red", kde=True,bins=50, label='target = 0')
sns.distplot(t1['creddebt'],color="blue", kde=True,bins=50, label='target = 1')
plt.legend()
plt.show()

# %%
t0 = train.loc[train['default'] == 0]
t1 = train.loc[train['default'] == 1]
plt.figure(figsize=(16,6))
plt.title("Distribution of othdebt in the train set for different target")
sns.distplot(t0['othdebt'],color="red", kde=True,bins=50, label='target = 0')
sns.distplot(t1['othdebt'],color="blue", kde=True,bins=50, label='target = 1')
plt.legend()
plt.show()

# %%
# Finding correlation of each variable with each variable

corr=train.corr()
corr
# Out:
#                age        ed    employ   address    income   debtinc  \
# age       1.000000  0.022325  0.536497  0.597591  0.478710  0.016398
# ed        0.022325  1.000000 -0.153621  0.056919  0.235190  0.008838
# employ    0.536497 -0.153621  1.000000  0.322334  0.619681 -0.031182
# address   0.597591  0.056919  0.322334  1.000000  0.316245  0.011323
# income    0.478710  0.235190  0.619681  0.316245  1.000000 -0.026777
# debtinc   0.016398  0.008838 -0.031182  0.011323 -0.026777  1.000000
# creddebt  0.295207  0.088274  0.403694  0.208435  0.570199  0.501767
# othdebt   0.340217  0.165459  0.406091  0.226514  0.610659  0.584870
# default  -0.137657  0.114676 -0.282978 -0.164451 -0.070970  0.389575
#
#           creddebt   othdebt   default
# age       0.295207  0.340217 -0.137657
# ed        0.088274  0.165459  0.114676
# employ    0.403694  0.406091 -0.282978
# address   0.208435  0.226514 -0.164451
# income    0.570199  0.610659 -0.070970
# ...

# %%
# Set the matplotlib figure 
fig, ax=plt.subplots(figsize=(15,10))

# Draw the heatmap
_= sns.heatmap(corr,  ax=ax, annot=True,   vmin=-1, linewidths=0.1)

# %%
pd.pandas.set_option('max_rows',None)
pd.pandas.set_option('max_columns',None)

# %%
a=train[['age','income','creddebt','othdebt','employ','debtinc','address','default']].groupby(['default']).agg(['mean','median','std'])

# %%
a.transpose()
#a
# Out:
# default                0.0        1.0
# age      mean    35.514507  33.010929
#          median  35.000000  31.000000
#          std      7.707736   8.517589
# income   mean    47.154739  41.213115
#          median  36.000000  29.000000
#          std     34.220150  43.115529
# creddebt mean     1.245493   2.423865
#          median   0.729000   1.376844
#          std      1.422312   3.232522
# othdebt  mean     2.773409   3.862807
#          median   1.879790   2.529508
#          std      2.813939   4.263684
# employ   mean     9.508704   5.224044
#          median   9.000000   3.000000
#          std      6.663741   5.542946
# debtinc  mean     8.679304  14.727869
#          median   7.300000  13.800000
#          std      5.615197   7.902798
# address  mean     8.945841   6.393443
#          median   8.000000   5.000000
#          std      7.000621   5.925208

# %%
train[['income','default']].groupby(['default']).agg(['mean','median'])
# Out:
#             income
#               mean median
# default
# 0.0      47.154739     36
# 1.0      41.213115     29

# %%
train[['creddebt','default']].groupby(['default']).agg(['mean','median'])
# Out:
#          creddebt
#              mean    median
# default
# 0.0      1.245493  0.729000
# 1.0      2.423865  1.376844

# %%
train[['othdebt','default']].groupby(['default']).agg(['mean','median'])
# Out:
#           othdebt
#              mean    median
# default
# 0.0      2.773409  1.879790
# 1.0      3.862807  2.529508

# %%
train[['employ','default']].groupby(['default']).agg(['mean','median'])
# Out:
#            employ
#              mean median
# default
# 0.0      9.508704      9
# 1.0      5.224044      3

# %%
# Boxplot of outlier analysis 

f, ax = plt.subplots(figsize=(15,10))
fig = sns.boxplot(data=train)

# %%
# Scatter plot of outlier analysis with income 

plt.figure(figsize=(12,8))
plt.scatter(x = train.debtinc, y = train.income)
plt.xlabel("debtinc", fontsize=13)
plt.ylabel("income", fontsize=13)
plt.ylim(0,400)
# Out:
# (0, 400)

# %%
# Dropping far values which are not in range 

train.drop(train[(train['debtinc'] > 35) | (train['income'] > 300)].index , inplace = True)

# %%
plt.figure(figsize=(12,8))
plt.scatter(x = train.creddebt, y = train.income)
plt.xlabel("creddebt", fontsize=13)
plt.ylabel("income", fontsize=13)
plt.ylim(0,400)
# Out:
# (0, 400)

# %%
train.drop(train[(train['creddebt'] > 20)].index , inplace = True)

# %%
# Importing libraries for preprocessing

from sklearn.preprocessing import normalize,MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler

# %%
num_cols = train._get_numeric_data().columns

# %%
min_max_scaler = MinMaxScaler()
robust = RobustScaler()
train[num_cols] = min_max_scaler.fit_transform(train[num_cols])

# %%
# Setting the target variable in y variable

y=train['default']
train.drop(['default'],axis=1, inplace=True)

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

# %%
# Splitting the train data into train and valid data with stratification in 80:20 ratio

X_train, X_valid, y_train, y_valid  = train_test_split(train,y,test_size=0.20, stratify=y,random_state=0)

# %% [markdown]
# ## Algorithms

# %% [markdown]
# 1. Logistic Regression

# %%
logistic=LogisticRegression()
clf_LR=logistic.fit(X_train,y_train)
y_pred_LR = clf_LR.predict(X_valid)
LR=logistic.score(X_valid,y_valid)
# Out:
# /Users/devsingh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
LR
# Out:
# 0.7985611510791367

# %%
confusion_matrix(y_valid,y_pred_LR)
# Out:
# array([[100,   3],
#        [ 25,  11]])

# %%
print(classification_report(y_valid, y_pred_LR))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.97      0.88       103
#          1.0       0.79      0.31      0.44        36
#
#     accuracy                           0.80       139
#    macro avg       0.79      0.64      0.66       139
# weighted avg       0.80      0.80      0.76       139

# %% [markdown]
# 2. Decision Tree

# %%
clf_DT = DecisionTreeClassifier(random_state=0)
clf_DT.fit(X_train,y_train)
y_pred_DT=clf_DT.predict(X_valid)
DT=accuracy_score(y_valid,y_pred_DT)

# %%
confusion_matrix(y_valid,y_pred_DT)
# Out:
# array([[82, 21],
#        [21, 15]])

# %%
print(classification_report(y_valid, y_pred_DT))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80       103
#          1.0       0.42      0.42      0.42        36
#
#     accuracy                           0.70       139
#    macro avg       0.61      0.61      0.61       139
# weighted avg       0.70      0.70      0.70       139

# %% [markdown]
# 3. K-NN

# %%
clf_KNN=KNeighborsClassifier(n_neighbors=5, p=2, metric='euclidean')
clf_KNN.fit(X_train,y_train)
y_pred_KNN=clf_KNN.predict(X_valid)
KNN = accuracy_score(y_valid, y_pred_KNN)

# %%
KNN
# Out:
# 0.7410071942446043

# %%
confusion_matrix(y_valid,y_pred_KNN)
# Out:
# array([[88, 15],
#        [21, 15]])

# %%
print(classification_report(y_valid, y_pred_KNN))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.85      0.83       103
#          1.0       0.50      0.42      0.45        36
#
#     accuracy                           0.74       139
#    macro avg       0.65      0.64      0.64       139
# weighted avg       0.73      0.74      0.73       139

# %% [markdown]
# 4. Random Forest Classifier

# %%
clf_RFC = RandomForestClassifier(random_state=0)
clf_RFC.fit(X_train,y_train)
Y_pred_RFC = clf_RFC.predict(X_valid)
RFC=accuracy_score(y_valid, Y_pred_RFC)
RFC
# Out:
# /Users/devsingh/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.762589928057554

# %%
pd.crosstab(y_valid,Y_pred_RFC,rownames=['Actual'], colnames=['Prediction'])
# Out:
# Prediction  0.0  1.0
# Actual
# 0.0          95    8
# 1.0          25   11

# %%
print(classification_report(y_valid, Y_pred_RFC))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.92      0.85       103
#          1.0       0.58      0.31      0.40        36
#
#     accuracy                           0.76       139
#    macro avg       0.69      0.61      0.63       139
# weighted avg       0.74      0.76      0.73       139

# %% [markdown]
# 5. Support Vector Machine

# %%
from sklearn.svm import SVC
from sklearn import svm

# %%
clf_SVM = svm.SVC(kernel='linear')
clf_SVM.fit(X_train,y_train)
Y_pred_SVC=clf_SVM.predict(X_valid)
SVC=metrics.accuracy_score(y_valid,Y_pred_SVC)

# %%
pd.crosstab(y_valid,Y_pred_SVC,rownames=['Actual'], colnames=['Prediction'])
# Out:
# Prediction  0.0  1.0
# Actual
# 0.0         102    1
# 1.0          26   10

# %%
print(classification_report(y_valid, Y_pred_SVC))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.99      0.88       103
#          1.0       0.91      0.28      0.43        36
#
#     accuracy                           0.81       139
#    macro avg       0.85      0.63      0.65       139
# weighted avg       0.83      0.81      0.76       139

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import make_pipeline
    

kfold = StratifiedKFold(n_splits=5,
                        random_state=1).split(X_train, y_train)

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(logistic,
                         X=X_train,
                         y=y_train,
                         cv=10,
                         n_jobs=1)
print('CV accuracy scores: %s' % scores)
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# CV accuracy scores: [0.84210526 0.77192982 0.80357143 0.85714286 0.72727273 0.78181818
#  0.78181818 0.81818182 0.74545455 0.8       ]
# CV accuracy: 0.793 +/- 0.038
# /Users/devsingh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/devsingh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/devsingh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...
